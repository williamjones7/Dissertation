# %%
import numpy as np
import pandas as pd
from functions import *
from schemes import *
from plot import * 
from Kepler import *
from adaptive import *

# %%
# gravity
G = 1

# mass ratio & eccentricity 
q = 1.0 # q = m2 / m1
e = 0.5

m1 = 1 # central mass
m2 = q # orbiting mass
mu = G * (m1 + m2) 

# position
r1 = np.array([0,0.0,0.0], dtype="float64")
r2 = np.array([1,0.0,0.0], dtype="float64")

# velocity 
v1 = np.array([0,0.0,0], dtype="float64")
v2 = np.array([0,np.sqrt((1 + q)*(1 + e)),0], dtype="float64")

# create initial vectors
r0s = np.array([r1,r2])
v0s = np.array([v1,v2])
masses = np.array([m1, m2])

T = 50
h0 = 0.01

# %%
colours = [    "#ff7f0e",  # orange
    "#2ca02c",  # green
    "#d62728",  # red
    "#9467bd",  # purple 
    ]

schemes = [EulerCromerStep, LeapfrogStep, RK4Step, PEFRLStep]
scales = np.array([0.0011772945723510023, 0.16326434633255257, 0.39325079637589083,  0.6])
names = ['Symplectic Euler', 'Leapfrog', 'RK4', 'Forest-Ruth', 'Scipy']

# %%
std_Es = []
adapt_Es = []
std_ts = []
adapt_ts = []
all_hs = []
adapt_times = []
for i, scheme in enumerate(schemes):
    adapt_traj = run_adaptive(scheme, 0, T, h0, r0s, v0s, G, masses, scaleh = scales[i])
    # traj = run_scheme(scheme, 0, T, h0, r0s, v0s, G, masses)

    t_adapt = adapt_traj[0]
    # t_traj = traj[0]

    # std_ts.append(t_traj)
    adapt_ts.append(t_adapt)
    adapt_times.append(adapt_traj[-1])

    E_adapt = adapt_traj[3]
    # E_traj = traj[3]

    rel_E_adapt = RelativeEnergy(E_adapt)
    # rel_E_traj = RelativeEnergy(E_traj)

    # std_Es.append(rel_E_traj)
    adapt_Es.append(rel_E_adapt)

    hs = [t_adapt[i + 1] - t_adapt[i] for i in range(len(t_adapt)-1)]
    all_hs.append(hs)

    # plot2D(adapt_traj, masses, f'Adaptive {names[i]}')
    PlotOrbits(adapt_traj, names[i], T, 'Adaptive', masses)

scipy_traj = run_scipy(0, T, h0, r0s, v0s, G, masses)
scipy_t = scipy_traj[0]
scipy_E = scipy_traj[3]
scipy_time = scipy_traj[-1]

# %%
fig, ax = plt.subplots(1,1, figsize = (14,7))

for i, scheme in enumerate(schemes):

    # std_E = std_Es[i]
    adapt_E = adapt_Es[i]
    # t_std = std_ts[i]
    t_adapt = adapt_ts[i]
    # ax.plot(t_std, std_E, label = f'Standard {names[i]}, time = {std_times[i]}', linestyle = 'dashed', color = colours[i])
    ax.plot(t_adapt, adapt_E, label = f'Adaptive {names[i]}, time = {np.round(adapt_times[i],3)}', linestyle = 'solid', color = colours[i])

ax.plot(scipy_t, RelativeEnergy(scipy_E), label = f'Scipy, time = {np.round(scipy_time, 3)}', linestyle = '--', color = 'brown')
ax.text(0.02, 0.98, f'Eccentricity = {e}, T = {T}', transform=ax.transAxes, 
            va='top', fontsize = 12)
    
# ax.set_yscale('log')
ax.set_xlabel('Time', fontsize = 12)
ax.set_ylabel('Relative Energy Error (%)', fontsize = 12)
plt.legend(loc = 'upper right', fontsize=12)
plt.tight_layout()
plt.savefig(f'Plots/Adaptive/Adaptive Energy Comparison, Eccentricity={e}.pdf', format = 'pdf')

# %%
scales = np.array([0.0011772945723510023, 0.16326434633255257, 0.35,  1.0])

std_Es = []
adapt_Es = []
std_ts = []
adapt_ts = []
all_hs = []
adapt_times = []
for i, scheme in enumerate(schemes):
    adapt_traj = run_adaptive_symplectic(scheme, 0, T, h0, r0s, v0s, G, masses, scaleh = scales[i])
    # traj = run_scheme(scheme, 0, T, h0, r0s, v0s, G, masses)

    t_adapt = adapt_traj[0]
    # t_traj = traj[0]

    # std_ts.append(t_traj)
    adapt_ts.append(t_adapt)
    adapt_times.append(adapt_traj[-1])

    E_adapt = adapt_traj[3]
    # E_traj = traj[3]

    rel_E_adapt = RelativeEnergy(E_adapt)
    # rel_E_traj = RelativeEnergy(E_traj)

    # std_Es.append(rel_E_traj)
    adapt_Es.append(rel_E_adapt)

    hs = [t_adapt[i + 1] - t_adapt[i] for i in range(len(t_adapt)-1)]
    all_hs.append(hs)

    # plot2D(adapt_traj, masses, f'Adaptive {names[i]}')
    PlotOrbits(adapt_traj, names[i], T, 'Adaptive', masses)

scipy_traj = run_scipy(0, T, h0, r0s, v0s, G, masses)
scipy_t = scipy_traj[0]
scipy_E = scipy_traj[3]
scipy_time = scipy_traj[-1]

# %%
fig, ax = plt.subplots(1,1, figsize = (14,7))

for i, scheme in enumerate(schemes):

    # std_E = std_Es[i]
    adapt_E = adapt_Es[i]
    # t_std = std_ts[i]
    t_adapt = adapt_ts[i]
    # ax.plot(t_std, std_E, label = f'Standard {names[i]}, time = {std_times[i]}', linestyle = 'dashed', color = colours[i])
    ax.plot(t_adapt, adapt_E, label = f'Adaptive {names[i]}, time = {np.round(adapt_times[i],3)}', linestyle = 'solid', color = colours[i])

ax.plot(scipy_t, RelativeEnergy(scipy_E), label = f'Scipy, time = {np.round(scipy_time, 3)}', linestyle = '--', color = 'brown')
ax.text(0.02, 0.98, f'Eccentricity = {e}, T = {T}', transform=ax.transAxes, 
            va='top', fontsize = 12)
    
# ax.set_yscale('log')
ax.set_xlabel('Time', fontsize = 12)
ax.set_ylabel('Relative Energy Error (%)', fontsize = 12)
plt.legend(loc = 'upper right', fontsize=12)
plt.tight_layout()
plt.savefig(f'Plots/Adaptive/Adaptive Energy Comparison, Eccentricity={e}.pdf', format = 'pdf')
